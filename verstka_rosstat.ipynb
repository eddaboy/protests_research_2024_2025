# %%
import pandas as pd

# %%
df = pd.read_csv("D:\mainpy\муниципалитеты (чужие)\дополнительные\Численность населения по полу и возрасту\data_Y48112014_112_v20241111.csv", sep=";")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\micha\AppData\Local\Temp\ipykernel_20300\64735994.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df = pd.read_csv("D:\mainpy\муниципалитеты (чужие)\дополнительные\Численность населения по полу и возрасту\data_Y48112014_112_v20241111.csv", sep=";")
# C:\Users\micha\AppData\Local\Temp\ipykernel_20300\64735994.py:1: DtypeWarning: Columns (14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:\mainpy\муниципалитеты (чужие)\дополнительные\Численность населения по полу и возрасту\data_Y48112014_112_v20241111.csv", sep=";")
#          indicator_section_code indicator_section indicator_code  \
# 0                            31         Население      Y48112014
# 1                            31         Население      Y48112014
# 2                            31         Население      Y48112014
# ...

# %%
df = df.drop(columns=['indicator_section_code',	'indicator_section','indicator_code','indicator_name','region_id','region_name','mun_level','mun_district'])

# %%
df = df.drop(columns=['oktmo','mun_type','mun_type_oktmo','oktmo_stable','oktmo_history','oktmo_year_from','oktmo_year_to'])
df
# Out:
#           grup_2       vozr                     municipality  year  \
# 0        Мужчины      До 30  Залесовский муниципальный округ  2022
# 1        Мужчины         44  Залесовский муниципальный округ  2022
# 2          Всего          1  Залесовский муниципальный округ  2022
# 3        Женщины       0‒14  Залесовский муниципальный округ  2022
# 4        Женщины         32  Залесовский муниципальный округ  2022
# ...          ...        ...                              ...   ...
# 8597257    Всего  Старше 65                 Город Биробиджан  2023
# 8597258    Всего          7                 Город Биробиджан  2023
# 8597259    Всего         22                 Город Биробиджан  2023
# 8597260    Всего          5                 Город Биробиджан  2023
# 8597261  Женщины      60‒65                 Город Биробиджан  2023
#
#          indicator_value indicator_unit indicator_period comment
# 0                 2269.0        Человек      На 1 января      CD
# ...

# %%
df = df.drop(columns=['comment'])
df = df.drop(columns=['indicator_period'])
df
# Out:
#           grup_2       vozr                     municipality  year  \
# 0        Мужчины      До 30  Залесовский муниципальный округ  2022
# 1        Мужчины         44  Залесовский муниципальный округ  2022
# 2          Всего          1  Залесовский муниципальный округ  2022
# 3        Женщины       0‒14  Залесовский муниципальный округ  2022
# 4        Женщины         32  Залесовский муниципальный округ  2022
# ...          ...        ...                              ...   ...
# 8597257    Всего  Старше 65                 Город Биробиджан  2023
# 8597258    Всего          7                 Город Биробиджан  2023
# 8597259    Всего         22                 Город Биробиджан  2023
# 8597260    Всего          5                 Город Биробиджан  2023
# 8597261  Женщины      60‒65                 Город Биробиджан  2023
#
#          indicator_value indicator_unit
# 0                 2269.0        Человек
# 1                   87.0        Человек
# ...

# %%
df.to_csv("поло_возраст.csv", index=False)

# %%
df
# Out:
#           grup_2       vozr                     municipality  year  \
# 0        Мужчины      До 30  Залесовский муниципальный округ  2022
# 1        Мужчины         44  Залесовский муниципальный округ  2022
# 2          Всего          1  Залесовский муниципальный округ  2022
# 3        Женщины       0‒14  Залесовский муниципальный округ  2022
# 4        Женщины         32  Залесовский муниципальный округ  2022
# ...          ...        ...                              ...   ...
# 8597257    Всего  Старше 65                 Город Биробиджан  2023
# 8597258    Всего          7                 Город Биробиджан  2023
# 8597259    Всего         22                 Город Биробиджан  2023
# 8597260    Всего          5                 Город Биробиджан  2023
# 8597261  Женщины      60‒65                 Город Биробиджан  2023
#
#          indicator_value indicator_unit
# 0                 2269.0        Человек
# 1                   87.0        Человек
# ...
